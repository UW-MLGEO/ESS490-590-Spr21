# %% [markdown]
# # Module 2: Lesson 1, some basics

# %% [markdown]
# ### Arrays, distributions, basic plotting

# %%
N = 100# number of points in the array

x=rand(Float32,N)
y=2*ones(Float32,N).*rand(Float32,N)-ones(Float32,N)
# Out:
# 100-element Vector{Float32}:
#  -0.5172281
#  -0.24023509
#  -0.6274605
#   0.6237304
#   0.15162253
#   0.22828698
#   0.49549747
#  -0.76833296
#  -0.5345547
#   0.27637005
#   0.79409933
#   0.05108142
#   0.3837974
#   ⋮
#   0.35375476
#  -0.33672094
#   0.96750116
#   0.30533242
#  -0.8974371
#   0.67965126
#   0.031244516
#   0.3398285
#   0.1500957
#   0.70902085
#  -0.82739687
#   0.22496128

# %%
using Random
x=rand(Float32,(N))
# Out:
# 100-element Vector{Float32}:
#  0.8677267
#  0.8967049
#  0.9140787
#  0.5587143
#  0.5588144
#  0.9963248
#  0.9644909
#  0.65406084
#  0.717263
#  0.4981693
#  0.5691482
#  0.34993804
#  0.55403745
#  ⋮
#  0.8412695
#  0.70949495
#  0.4463514
#  0.8134177
#  0.5796877
#  0.9671382
#  0.75747895
#  0.9519402
#  0.49894047
#  0.35717142
#  0.9683368
#  0.031271815

# %%
using Plots

# %%
plot(x)
